# %% [markdown]
# # DC-EGM med Max's Model

# %% [markdown]
# ## load packages and dependencies

# %%
#Dependencies
import jax.numpy as jnp
import numpy as np
from dcegm.pre_processing.setup_model import setup_model
import jax

from typing import Tuple

import pandas as pd
import matplotlib.pyplot as plt

from dcegm.sim_interface import get_sol_and_sim_func_for_model
from dcegm.simulation.sim_utils import create_simulation_df

from scipy.optimize import minimize

import statsmodels.api as sm

import os

import sys
sys.path.insert(0,"/Users/frederiklarsen/thesis/thesis")
sys.path.insert(1,"/Users/frederiklarsen/dcegm/")

from model_functions.utility import utility_functions
from model_functions.final_period_utility import final_period_utility
from model_functions.budget import budget_dcegm
from model_functions.state_space_functions import create_state_space_function_dict
from model_functions.compute_moments import compute_simulation_moments
from model_functions.compute_moments import compute_simulation_moments_with_ci
from model_functions.plots import plot_empirical_vs_simulated_with_ci
from model_functions.estimation import estimate_msm

from first_step.mortality import prob_survival

from dcegm.interface import validate_exogenous_processes

# ── Configurating file-location -────────────────────────────────────────────────
DATA_DIR    = "/Users/frederiklarsen/Data"
FILE_UDD1   = os.path.join(DATA_DIR, "momenter/moments_udd1.txt")
FILE_UDD2   = os.path.join(DATA_DIR, "momenter/moments_udd2.txt")
FILE_UDD3   = os.path.join(DATA_DIR, "momenter/moments_udd3.txt")
Mortality   = os.path.join(DATA_DIR, "mortality.xlsx")
# ────────────────────────────────────────────────────────────────────────────────

##### Git Commit Hash ee6660e #####
##### Git Branch = origin(aux-budget) #####
# ────────────────────────────────────────────────────────────────────────────────


jax.config.update("jax_enable_x64", True)
# Out:
# MLE estimates: alpha1 = 0.000417, alpha2 = 0.099277

# %% [markdown]
# ## Load Data

# %%
# Read CSV
df_edu = pd.read_csv(FILE_UDD2)

# read mortality and discard second and third column
df_mort = pd.read_excel(Mortality, sheet_name="DOD", usecols=[0, 3])

# 2) standardize column name and remove _FREQ_ column
# Rename ALDER → age and remove _FREQ_ column if it exists
if "ALDER" in df_edu.columns:
    df_edu.rename(columns={"ALDER": "age"}, inplace=True)
if "_FREQ_" in df_edu.columns:
    df_edu.drop(columns=["_FREQ_"], inplace=True)

# 4) (Optional) Control print
# print(df_edu)

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
choices = np.arange(5) # 5 choices

options = {
    "model_params": {
        #"quadrature_points_stochastic": 5, 
        "n_quad_points_stochastic": 25,
        "n_periods": n_periods,
        "choices": choices, # 4 choices
        "hours": jnp.array([0,250,750,1200,1700]), #list 
        "max_hours": 1500,
        "start_age": 30,
        "inc_threshold": 6.0,
        "tax_base_rate": 0.37,
        "tax_top_rate": 0.5,
        "retirement_age": 67,
        "oap_base_amount":0.80328,
        "oap_max_supplement": 0.92940,
        "supp_threshold": 0.79300,
        "oap_threshold": 3.3592,
        "supp_reduction_rate": 0.309,
        "oap_reduction_rate": 0.3,
        "alpha1": 0.000417, # independently estimated parameter for survival probability
        "alpha2": 0.1,  # independently estimated parameter for survival probability
        "max_init_experience": 5,
        "max_ret_period": 45, # Age 75
        "min_ret_period": 30, # Age 60
    },
    "state_space": {
        "n_periods": n_periods,
        "choices": choices, # 4 choices
        "continuous_states": {
            "wealth": np.linspace(0, 50, 20),
            "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
        "exogenous_processes": {
            "survival": {
                "transition": prob_survival,
                "states": [0, 1],
            },
        },
    },
}

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# # Structural Estimation

# %% [markdown]
# ## Initiatal parameters - some are estimated above, the rest to be structuraly estimated

# %%
beta0, beta1, beta2 = np.loadtxt("/Users/frederiklarsen/dcegm/Speciale/first_step/wage_params_udd2.txt")

params_initial = {}
params_initial["interest_rate"] = 0.01
params_initial["sigma"] = 0.11436398 # income shock scale
params_initial["lambda"] = 0.96854512 # taste shock scale

# discount factor
params_initial["beta"] = 0.99633022

# parameters for the utility function
params_initial["rho"]=0.77007267

# disutility of each hours choice
params_initial["gamma"]=jnp.array([0.7949593,1.65520093,2.12902941,1.73385035]) 

# Age component disutility
params_initial["kappa1"]=0.06931974
params_initial["kappa2"]=0.00377771

# transsition cost
params_initial["phi"]=0.99926288

# bequest parameters
params_initial["b_scale"]=1.53314057
params_initial["xi"]=0.18549496


# labor market parameters
params_initial["eta_edu1"]=1.81532136


# mortality parameters
params_initial["alpha1"]=0.000417
params_initial["alpha2"]=0.099277



# wage parameters
# ----- EDU LEVEL 2 -----
params_initial["beta0"]=beta0
params_initial["beta1"]=beta1
params_initial["beta2"]=beta2


params=params_initial.copy()

# %% [markdown]
# ### Setup the model

# %%
model = setup_model(
    options=options,
    state_space_functions=create_state_space_function_dict(),
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm,
)
# Out:
# State specific choice set not provided. Assume all choices are available in every state.
# Update function for state space not given. Assume states only change with an increase of the period and lagged choice.
# Sparsity condition not provided. Assume all states are valid.
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  50
# Model setup complete.

# %%
# # validate model
# validate_exogenous_processes(model, params)

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# ## Initial values for simulating.

# %%
# Select number of individuals for simulation
n_individuals = 10000

seed = 132



key = jax.random.PRNGKey(0)              # whatever seed you like
n = n_individuals                        # how many draws

# define your class‐labels and their probabilities
labels = jnp.array([0, 1, 2, 3], dtype=jnp.int32)
probs  = jnp.array([0.25, 0.20, 0.25, 0.509])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)
# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals),       # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 0.8).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals), # Every individual starts with 1 (alive)
}

# Set wealth at beginning of period, which is the starting wealth for every individual. 
wealth_initial = jnp.full(n_individuals, 0.59)   # Every individual starts with 59k wealth - to be adjusted based on the actual moments

# %% [markdown]
# ## Simulate model

# %%
sim_func_aux = get_sol_and_sim_func_for_model(
    model=model,
    states_initial=states_initial,
    wealth_initial=wealth_initial,
    n_periods=options["state_space"]["n_periods"],
    seed=seed,
)

# %%
output_dict_aux = sim_func_aux(params)

# %% [markdown]
# ## Convert simulation results to DataFrame

# %%
df_sim = create_simulation_df(output_dict_aux["sim_dict"])

#print to excel
#df_sim.to_excel("/Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Resultater/simulation_output.xlsx")


#print all individuals
#df_sim


#print a select individual
df_sim.loc[(slice(None), 20),:]
# Out:
#                 acc_exp  choice  consumption  experience  income_shock  \
# period agent
# 0      20           NaN       4     0.590000    0.800000      0.163204
# 1      20      5.855556       4     1.262252    0.855556      0.061936
# 2      20      6.790476       4     1.362291    0.895238     -0.090055
# 3      20      7.775000       4     1.400652    0.925000     -0.098052
# 4      20      8.792593       4     1.433332    0.948148      0.075217
# 5      20      9.833333       0     1.376632    0.966667     -0.030854
# 6      20     10.272727       4     1.452261    0.878788      0.246919
# 7      20     11.300000       4     1.485096    0.900000     -0.038156
# 8      20     12.343590       4     1.503363    0.917949     -0.147346
# 9      20     13.400000       4     1.517222    0.933333      0.080607
# 10     20     14.466667       4     1.537537    0.946667     -0.052187
# 11     20     15.541667       4     1.553717    0.958333     -0.092958
# 12     20     16.623529       4     1.568947    0.968627      0.084953
# 13     20     17.711111       3     1.574316    0.977778      0.062022
# 14     20     18.557895       4     1.600260    0.968421      0.114838
# 15     20     19.650000       4     1.622981    0.976667      0.220846
# 17     20         6.185144              4  0.000000   3.092572
# 18     20         6.088072              4  0.000000   3.044036
# 19     20         6.124000              4  0.000000   3.062000
# 20     20         5.830925              4  0.000000   3.673483
# 21     20         5.786426              4  0.000000   3.645449
# 22     20         4.611343              4  0.000000   2.905146
# 23     20         4.356825              4  0.000000   2.744800
# 24     20         5.687267              4  0.000000   3.582978
# 25     20         5.619937              4  0.000000   3.540560
# 26     20         5.736978              4  0.000000   3.614296
# 27     20         6.499876              4  0.000000   3.249938
# 28     20         5.382118              4  0.000000   3.390734
# 29     20         5.882581              4  0.000000   3.706026
# 30     20         6.654055              4  0.000000   3.327027
# 31     20         0.894640              1  0.000000   0.563623
# 32     20         0.000000              0  0.000000   0.000000
# 33     20         0.000000              0  0.000000   0.000000
# 34     20         0.000000              0  0.000000   0.000000
# 35     20         0.000000              0  0.000000   0.000000
# 36     20         0.000000              0  0.000000   0.000000
# 37     20         0.000000              0  0.951747   0.000000
# 38     20         0.000000              0  0.000000   0.000000
# 39     20         0.000000              0  0.000000   0.000000
# 40     20         0.000000              0  0.000000   0.000000
# 41     20         0.000000              0  0.000000   0.000000
# 42     20         0.000000              0  0.000000   0.000000
# 43     20         0.000000              0  0.000000   0.000000
# 44     20         0.000000              0  0.000000   0.000000
# 45     20         0.000000              0  0.000000   0.000000
# 46     20         0.000000              0  0.000000   0.000000
# 47     20         0.000000              0  0.000000   0.000000
# 48     20         0.000000              0  0.000000   0.000000
# 49     20         0.000000              0  0.000000   0.000000
# 50     20         0.000000              0  0.000000   0.000000
# 51     20         0.000000              0  0.000000   0.000000
# 52     20         0.000000              0  0.000000   0.000000
# 53     20         0.000000              0  0.000000   0.000000
# 54     20         0.000000              0  0.000000   0.000000
#
#               period_pension  ...  taste_shocks_0  taste_shocks_1  \
# period agent                  ...
# 0      20                NaN  ...        0.242039       -0.530902
# 1      20           0.000000  ...       -1.196616        0.701125
# 2      20           0.000000  ...       -0.986671        0.858799
# 3      20           0.000000  ...       -1.514331        0.352353
# 4      20           0.000000  ...       -0.288386        0.640938
# 5      20           0.000000  ...        1.708537       -1.417620
# 6      20           0.000000  ...       -0.690122       -0.531204
# 7      20           0.000000  ...        0.240256       -0.406567
# 8      20           0.000000  ...        0.834171        0.392599
# 9      20           0.000000  ...       -2.045932       -0.402281
# 10     20           0.000000  ...        0.481432        1.806714
# 11     20           0.000000  ...       -0.242767        0.073314
# 12     20           0.000000  ...       -0.634111        0.054238
# 13     20           0.000000  ...       -0.455129       -1.672753
# 14     20           0.000000  ...       -1.072764       -0.894626
# 15     20           0.000000  ...       -1.459651        0.158561
# 16     20           0.000000  ...       -1.458770        0.158563
# 17     20           0.000000  ...       -0.734792        1.535270
# 18     20           0.000000  ...       -0.769234        1.328021
# 19     20           0.000000  ...        0.254986        0.721799
# 20     20           0.000000  ...        1.418794       -0.015000
# 21     20           0.000000  ...        2.027699        1.428836
# 22     20           0.000000  ...        0.307650       -0.273578
# 23     20           0.000000  ...       -0.793869        0.361386
# 24     20           0.000000  ...       -1.865593        0.158994
# 43   0.380516  0.000000   0.023912       1.0         1.964590           7594
# 44   0.343590  0.000000   0.013377       1.0         1.980950           7379
# 45   0.329791  0.000000   0.013498       1.0         1.997541           7142
# 46   0.333091  0.000000   0.010683       1.0         2.013769           6859
# 47   0.326385  0.000000   0.006620       1.0         2.030396           6577
# 48   0.345779  0.000000   0.004326       1.0         2.047719           6295
# 49   0.321002  0.000000   0.004860       1.0         2.064605           5989
# 50   0.314248  0.000000   0.002788       1.0         2.081912           5644
# 51   0.289342  0.000000   0.002016       1.0         2.099626           5295
# 52   0.412479  0.000000   0.001253       1.0         2.116770           4947
# 53   0.343051  0.000000   0.000532       1.0         2.135122           4535
# 54   0.331515  0.000000   0.002536       1.0        24.786191           4163
#
#     avg_experience  avg_labor_income
# 0         0.000000          0.000000
# 1         5.762801          2.294706
# 2         6.497743          2.630026
# 3         7.242476          2.904701
# 4         8.008979          3.094463
# 5         8.799831          3.282253
# 6         9.614446          3.430548
# 7        10.448572          3.577257
# 8        11.299752          3.706313
# 9        12.163220          3.800682
# 10       13.048824          3.958719
# 11       13.945785          4.085642
# 12       14.853952          4.167641
# 13       15.768329          4.268198
# 14       16.691228          4.362058
# 15       17.620930          4.436117
# 16       18.556512          4.526689
# 17       19.496368          4.594168
# 18       20.442412          4.683867
# 19       21.391426          4.748627
# 20       22.342035          4.808009
# 21       23.292314          4.859504
# 22       24.246161          4.923775
# 23       25.204332          4.998226
# 24       26.156615          5.008599
# 25       27.110492          5.072202
# 26       28.056521          5.042952
# 27       28.990985          5.055265
# 28       29.897650          4.948571
# 29       30.775870          4.877729
# 30       31.607239          4.719744
# 31       32.376547          4.508640
# 32       33.049208          4.180890
# 33       33.618642          3.845473
# 34       34.091294          3.374381
# 35       34.457543          2.912674
# 36       34.722461          1.933362
# 37       34.881095          0.901190
# 38       35.007202          0.486935
# 39       35.111543          0.424648
# 40       35.211469          0.315604
# 41       35.307233          0.366137
# 42       35.387722          0.199673
# 43       35.474263          0.157455
# 44       35.550886          0.189516
# 45       35.625694          0.076731
# 46       35.685568          0.095121
# 47       35.745762          0.023046
# 48       35.816426          0.000000
# 49       35.874660          0.000000
# 50       35.934309          0.000000
# 51       36.001259          0.000000
# 52       36.040097          0.000000
# 53       36.100325          0.000000
# 54       36.160241          0.004324
#
# [55 rows x 21 columns]

# %% [markdown]
# # Estimation

# %%
#keep_cols = ["hours_0","hours_1","hours_2","hours_3", "hours_4","avg_wealth", "avg_hours"]
keep_cols = ["hours_1","hours_2","hours_3", "hours_4", "avg_hours"]
# keep_cols = ["hours_4", "avg_wealth"]
def crit_func_scipy(theta_array):
    """
    High-level objective function for MSM that updates all parameters,
    runs the simulation, computes simulated moments and compares them
    to empirical moments. The objective is the weighted sum of squared differences,
    where the weights are given by the inverse of the variances of the empirical moments.
    
    theta_array: a numpy array with 13 elements corresponding to:
       [rho, sigma, lambda, beta, rho, gamma1, gamma2, gamma3,
        beta0, beta1, beta2, kappa1, kappa2]
    """

    # fixed model params
    params["interest_rate"] = 0.01
    params["beta0"]=-7.3453
    params["beta1"]= 0.0522
    params["beta2"]=-0.0004
    # Update model parameters from theta_array
    params["sigma"] = theta_array[0]
    params["lambda"] = theta_array[1]
    params["beta"] = theta_array[2]
    params["rho"] = theta_array[3]
    params["gamma"] = jnp.array([theta_array[4], theta_array[5], theta_array[6], theta_array[7]])
    params["kappa1"] = theta_array[8]
    params["kappa2"] = theta_array[9]
    params["phi"] = theta_array[10]
    params["b_scale"] = theta_array[11]
    params["xi"] = theta_array[12]
    params["eta_edu1"] = theta_array[13]

    # Run the simulation
    output_dict_aux = sim_func_aux(params)
    df_sim = create_simulation_df(output_dict_aux["sim_dict"])

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(df_sim, start_age, hours_map)
    empirical_moms = df_edu  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]
    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    #print("Simulated moments shape:", sim_vals.shape)
    #print("Empirical moments shape:", emp_vals.shape)

    # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-6

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Crit value:", crit_val)
    return float(crit_val)

# Example initial guess with 12 parameters:params = {}

initial_guess = np.array([
    0.06973542,     # sigma
    1.07401674,     # lambda
    0.90057347,     # beta
    0.55956175,      # rho
    0.62325728, 1.37711103, 1.99822222, 1.29581208,  # gamma[0..3]
    0.05, 0.00348906, 1.68451544, 1.20993635,  # kappa1, kappa2, phi, b_scale
    0.08269232,     # xi
    1.5168022       # eta_edu1
], dtype=float)
result = minimize(crit_func_scipy, initial_guess, method="Nelder-Mead", options={'disp': True})
print("Optimization result:")
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 104
#      92 # Example initial guess with 12 parameters:params = {}
#      94 initial_guess = np.array([
#      95     0.06973542,     # sigma
#      96     1.07401674,     # lambda
#    (...)
#     102     1.5168022       # eta_edu1
#     103 ], dtype=float)
# --> 104 result = minimize(crit_func_scipy, initial_guess, method="Nelder-Mead", options={'disp': True})
#     105 print("Optimization result:")
#     106 print(result)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/scipy/optimize/_minimize.py:726, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     723 callback = _wrap_callback(callback, meth)
#     725 if meth == 'nelder-mead':
# --> 726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
#     729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/scipy/optimize/_optimize.py:833, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     831 try:
#     832     for k in range(N + 1):
# --> 833         fsim[k] = func(sim[k])
#     834 except _MaxFuncCallError:
#     835     pass
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/scipy/optimize/_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# Cell In[42], line 35, in crit_func_scipy(theta_array)
#      32 params["eta_edu1"] = theta_array[13]
#      34 # Run the simulation
# ---> 35 output_dict_aux = sim_func_aux(params)
#      36 df_sim = create_simulation_df(output_dict_aux["sim_dict"])
#      38 # Compute simulated moments - returning a dataframe similar to the actual data
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/pjit.py:338, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
# --> 338 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     339     fun, jit_info, *args, **kwargs)
#     340 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     341 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/pjit.py:188, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     185   args_flat = [*init_states, *args_flat]
#     187 try:
# --> 188   out_flat = pjit_p.bind(*args_flat, **p.params)
#     189 except pxla.DeviceAssignmentMismatchError as e:
#     190   fails, = e.args
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/core.py:2803, in AxisPrimitive.bind(self, *args, **params)
#    2799 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2800                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2801 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2802              else axis_main.with_cur_sublevel())
# -> 2803 return self.bind_with_trace(top_trace, args, params)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/core.py:955, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     953   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     954 else:
# --> 955   return primitive.impl(*tracers, **params)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/pjit.py:1738, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1729 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1730 cache_key = pxla.JitGlobalCppCacheKeys(
#    1731     donate_argnums=donated_argnums, donate_argnames=None,
#    1732     device=None, backend=None,
#    (...)
#    1736     out_layouts_treedef=None, out_layouts_leaves=out_layouts,
#    1737     use_resource_env=resource_env is not None)
# -> 1738 return xc._xla.pjit(
#    1739     name, f, call_impl_cache_miss, [], [], cache_key,
#    1740     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1741     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/pjit.py:1714, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1713 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1714   out_flat, compiled = _pjit_call_impl_python(
#    1715       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1716       out_shardings=out_shardings, in_layouts=in_layouts,
#    1717       out_layouts=out_layouts, resource_env=resource_env,
#    1718       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1719       inline=inline)
#    1720   pgle_profiler = _read_pgle_profiler(jaxpr)
#    1721   fastpath_data = _get_fastpath_data(
#    1722       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1723       jaxpr.consts, None, pgle_profiler)
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/pjit.py:1644, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1631     compile_options = {'fdo_profile': fdo_profile}
#    1633 # TODO(patrios): Do not pass mutable profile session through cached lowering
#    1634 # chain. Instead we need to move profilers dictionary to pxla module and use
#    1635 # module as key. Right now we can't do that since there is no way to evict _pjit_lower_cached cache for in PGLE mode.
#    1636 compiled = _resolve_and_lower(
#    1637     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1638     out_shardings=out_shardings, in_layouts=in_layouts,
#    1639     out_layouts=out_layouts, resource_env=resource_env,
#    1640     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1641     inline=inline, lowering_platforms=None,
#    1642     lowering_parameters=mlir.LoweringParameters(),
#    1643     pgle_profiler=pgle_profiler
# -> 1644 ).compile(compile_options)
#    1646 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1647 # This check is expensive so only do it if enable_checks is on.
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2345, in MeshComputation.compile(self, compiler_options)
#    2343 def compile(self, compiler_options=None) -> MeshExecutable:
#    2344   if self._executable is None or compiler_options is not None:
# -> 2345     executable = UnloadedMeshExecutable.from_hlo(
#    2346         self._name, self._hlo, **self.compile_args,
#    2347         compiler_options=compiler_options)
#    2348     if compiler_options is None:
#    2349       self._executable = executable
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2854, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2851       mesh = i.mesh  # type: ignore
#    2852       break
# -> 2854 xla_executable = _cached_compilation(
#    2855     hlo, name, mesh, spmd_lowering,
#    2856     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2857     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2858     compiler_options_keys, compiler_options_values, pgle_profiler)
#    2860 if auto_spmd_lowering:
#    2861   assert mesh is not None
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2666, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values, pgle_profiler)
#    2658 compile_options = create_compile_options(
#    2659     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2660     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2661     dev, pmap_nreps, compiler_options)
#    2663 with dispatch.log_elapsed_time(
#    2664     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2665     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2666   xla_executable = compiler.compile_or_get_cached(
#    2667       backend, computation, dev, compile_options, host_callbacks,
#    2668       pgle_profiler)
#    2669 return xla_executable
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/compiler.py:434, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     432 else:
#     433   log_persistent_cache_miss(module_name, cache_key)
# --> 434   return _compile_and_write_cache(
#     435       backend,
#     436       computation,
#     437       compile_options,
#     438       host_callbacks,
#     439       module_name,
#     440       cache_key,
#     441   )
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/compiler.py:662, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     653 def _compile_and_write_cache(
#     654     backend: xc.Client,
#     655     computation: ir.Module,
#    (...)
#     659     cache_key: str,
#     660 ) -> xc.LoadedExecutable:
#     661   start_time = time.monotonic()
# --> 662   executable = backend_compile(
#     663       backend, computation, compile_options, host_callbacks
#     664   )
#     665   compile_time = time.monotonic() - start_time
#     666   _cache_write(
#     667       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     668   )
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File /opt/anaconda3/envs/dcegm/lib/python3.11/site-packages/jax/_src/compiler.py:267, in backend_compile(backend, module, options, host_callbacks)
#     261     return backend.compile(
#     262         built_c, compile_options=options, host_callbacks=host_callbacks
#     263     )
#     264   # Some backends don't have `host_callbacks` option yet
#     265   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     266   # to take in `host_callbacks`
# --> 267   return backend.compile(built_c, compile_options=options)
#     268 except xc.XlaRuntimeError as e:
#     269   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
parameters = result.x
parameters
# Out:
# array([0.07171714, 1.230408  , 0.98860172, 0.58119488, 0.58106159,
#        1.29240286, 1.89210683, 1.31417314, 0.0469752 , 0.00325876,
#        1.44828217, 1.47729987, 0.08540317, 1.5305934 ])

# %%
# # Update the parameters in the params dictionary
params["sigma"] = parameters[0]     # 9.65073027e-02
params["lambda"] = parameters[1]    # 1.07262365e+00
params["beta"] = parameters[2]      # 9.11752988e-01
params["rho"] = parameters[3]       # 1.17380827e+00
params["gamma"] = jnp.array([parameters[4], parameters[5], parameters[6], parameters[7]]) # 2.28588031e+00, 3.13596501e+00, 3.24554860e+00, 1.62224838e+00
params["kappa1"] = parameters[8]    # -2.88010333e-02
params["kappa2"] = parameters[9]    # 1.69999238e-03
params["phi"] = parameters[10]      # 9.79359668e-03
params["b_scale"] = parameters[11]  # 2.36947625e+00
params["xi"] = parameters[12]       # 2.26797551e+00 
params["eta_edu1"] = parameters[13] # 4.58206470e-03

# %% [markdown]
# ## Plots

# %%
# 1) Define a grid of annual labor incomes from 0 to 100 000 DKK
income = np.linspace(0, 600_000, 500)

# 2) Calculate the supplement component:
#    income above the supplement threshold is taxed away at the supplement reduction rate
supp_threshold = options["model_params"]["supp_threshold"] * 100_000  # convert model units → DKK
supp_reduction_rate = options["model_params"]["supp_reduction_rate"]
income_over_supp = np.maximum(0.0, income - supp_threshold)
supplement = np.maximum(
    0.0,
    options["model_params"]["oap_max_supplement"] * 100_000  # max supplement in DKK
    - supp_reduction_rate * income_over_supp
)

# 3) Calculate the base pension component:
#    income above the OAP threshold reduces the base pension at the OAP reduction rate
oap_threshold = options["model_params"]["oap_threshold"] * 100_000
oap_reduction_rate = options["model_params"]["oap_reduction_rate"]
income_over_oap = np.maximum(0.0, income - oap_threshold)
base_pension = np.maximum(
    0.0,
    options["model_params"]["oap_base_amount"] * 100_000  # base amount in DKK
    - oap_reduction_rate * income_over_oap
)

# 4) Total annual pension is the sum of base pension and supplement
annual_pension = base_pension + supplement

# 5) Plot the piecewise-linear pension schedule
plt.figure(figsize=(8,5))
plt.plot(income, annual_pension, lw=2, label="Total Pension")
# mark the two thresholds
plt.axvline(supp_threshold, color="blue", linestyle="--", label="Supplement Threshold")
plt.axvline(oap_threshold, color="green", linestyle="--", label="Base Pension Threshold")
plt.xlabel("Annual Labor Income (DKK)")
plt.ylabel("Annual Old-Age Pension (DKK)")
plt.title("Old-Age Pension Schedule as a Function of Income")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
edu = df_edu.copy().loc[df_edu.age <= 75]       # empirical
moments_sim = compute_simulation_moments_with_ci(df_sim, start_age, hours_map)  # Call the function
moments_sim = moments_sim.loc[moments_sim.age <= 75]  # Filter simulated + CIs

# location to store plots in
BASE = "/Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer"
# print plots
plot_empirical_vs_simulated_with_ci(edu, moments_sim, BASE, out_subfolder="edu2")
# Out:
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/prob_work_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/hours_0_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/hours_1_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/hours_2_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/hours_3_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/hours_4_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/avg_wealth_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/work_work_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/nowork_nowork_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/avg_experience_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/avg_labor_income_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/avg_wage_over_age_edu2.png
# Saved /Users/frederiklarsen/Library/Mobile Documents/com~apple~CloudDocs/KU/Speciale/Figurer/edu2/avg_hours_over_age_edu2.png
